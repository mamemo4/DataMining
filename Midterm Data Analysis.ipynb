# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data.csv')

df = df.applymap(lambda s: s.lower() if type(s) == str else s)
df.head()
# Out:
#     GiftDate  GiftAmount  GiftCode ZipCode5 State  Gender MaritalStatus  \
# 0  1/12/1970      100.00         6    46802    in  female           NaN
# 1   4/6/1970    15000.00         6    55106    mn  female           NaN
# 2  4/28/1970     2300.00         6    63137    mo  female       married
# 3   5/1/1970     1000.00         6    50630    ia  female           NaN
# 4   5/7/1970     8664.38         6     8723    nj    male       married
#
#    BirthYear  AgeAtGift    Age  Deceased
# 0     1925.0       45.0   93.0         1
# 1     1902.0       68.0  116.0         1
# 2     1921.0       49.0   97.0         1
# 3     1896.0       74.0  122.0         1
# 4     1901.0       69.0  117.0         1

# %%
print("GiftDate \t |" + str(df.GiftDate.isnull().sum()))
print("GiftAmount \t |" + str(df.GiftAmount.isnull().sum()))
print("GiftCode \t |" + str(df.GiftCode.isnull().sum()))
print("ZipCode5 \t |" + str(df.ZipCode5.isnull().sum()))
print("State \t \t |" + str(df.State.isnull().sum()))
print("Gender \t \t |" + str(df.Gender.isnull().sum()))
print("MaritalStatus \t |" + str(df.MaritalStatus.isnull().sum()))
print("BirthYear \t |" + str(df.BirthYear.isnull().sum()))
print("AgeAtGift \t |" + str(df.AgeAtGift.isnull().sum()))
print("Age \t \t |" + str(df.Age.isnull().sum()))
print("Deceased \t |" + str(df.Deceased.isnull().sum()))
# Out:
# GiftDate 	 |0
# GiftAmount 	 |0
# GiftCode 	 |0
# ZipCode5 	 |386
# State 	 	 |110
# Gender 	 	 |1292
# MaritalStatus 	 |7727
# BirthYear 	 |7635
# AgeAtGift 	 |7635
# Age 	 	 |7635
# Deceased 	 |0

# %%
'''frequency distribution of all donations from females. each point represents frequency of donations within 
a range of approximately 500'''

import numpy as np

def graphFrequency(arrayValues, priceRange):
    arrayValues = np.array(arrayValues)
    freqDict = {}
    rangeCounter = 0
    amountRanges = np.linspace(min(arrayValues), max(arrayValues), max(arrayValues)/priceRange)
    amountRanges = [-1] + amountRanges
    for amount in np.sort(arrayValues):
        while amount > amountRanges[rangeCounter] and rangeCounter < len(amountRanges) - 1:
            rangeCounter += 1
        if amountRanges[rangeCounter] in freqDict:
            freqDict[amountRanges[rangeCounter]] += 1
        else:
            freqDict[amountRanges[rangeCounter]] = 1 
    x = []
    y = []
    for key, value in freqDict.items():
        x.append(key)
        y.append(value)
    return x, y
    
def plotDistributions(arrayValues, xArray, yArray):
    plt.figure(1)
    plt.rcParams['figure.figsize'] = [10,10]
    
    plt.subplot(221)
    plt.scatter(xArray, yArray)
    plt.gca().set_yscale("log")
    plt.gca().set_xscale("log")
    plt.title("Scatterplot Distribution")
    plt.xlabel("Amount Donation")
    plt.ylabel("Frequency")

    plt.subplot(222)
    plt.hist(arrayValues, 200)
    plt.gca().set_yscale("log")
    plt.gca().set_xscale("log")
    plt.title("Histogram Distribution")
    plt.xlabel("Amount Donation")
    plt.ylabel("Frequency")

    plt.show()

    
amountArrayFemale = []
for giftAmount in df.loc[df.Gender == "female"].GiftAmount:
    amountArrayFemale.append(giftAmount)

x, y = graphFrequency(amountArrayFemale, 500)
plotDistributions(amountArrayFemale, x, y)
# Out:
# C:\Users\Harrison Lu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:10: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#   # Remove the CWD from sys.path while we load stuff.

# %%
amountArrayMale = []
for giftAmount in df.loc[df.Gender == "male"].GiftAmount:
    amountArrayMale.append(giftAmount)

x, y = graphFrequency(amountArrayMale, 500)
plotDistributions(amountArrayMale, x, y)
# Out:
# C:\Users\Harrison Lu\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:10: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#   # Remove the CWD from sys.path while we load stuff.

# %%
'''look at span of data, impossible to estimate with just a few variables'''
def avgGiftGender(gender):
    total = 0
    count = 0
    for giftAmount in df.loc[df.Gender == gender].GiftAmount:
        total += giftAmount
        count += 1
    return total/count

amountArrayFemale = np.array(amountArrayFemale)
amountArrayMale = np.array(amountArrayMale)


# print("Average donation for females are: %s" % (avgGiftGender("female")))
# print("Average donation for males are: %s" % (avgGiftGender("male")))

print(f"Female donation mean: {np.average(amountArrayFemale)} with SD: {np.std(amountArrayFemale)}. Median: {np.median(amountArrayFemale)}")
print(f"Male donation mean: {np.average(amountArrayMale)} with SD: {np.std(amountArrayMale)}. Median: {np.median(amountArrayMale)}")

df2 = df.sort_values(by=['GiftAmount'], ascending = False)
print(df2.head())
df2 = df.sort_values(by=['GiftAmount'], ascending = True)
print(df2.head())
# Out:
# Female donation mean: 29627.987199012437 with SD: 128406.84594312916. Median: 4025.04
# Male donation mean: 31557.353209241475 with SD: 123429.64764353145. Median: 5000.0
#         GiftDate  GiftAmount  GiftCode ZipCode5 State  Gender MaritalStatus  \
# 7110   8/18/1997  5402615.00         5    65049    mo    male           NaN
# 19650  2/23/2010  4100000.00         4      NaN    ne    male       married
# 3191   3/12/1992  3867500.00         5    60143    il    male       widowed
# 9969    2/2/2001  3400000.00         5    88033    nm    male           NaN
# 24685   5/4/2016  3051002.21         4    48625    mi  female     separated
#
#        BirthYear  AgeAtGift    Age  Deceased
# 7110      1915.0       82.0  103.0         1
# 19650     1922.0       88.0   96.0         1
# 3191      1913.0       79.0  105.0         1
# 9969      1941.0       60.0   77.0         0
# 24685     1943.0       73.0   75.0         0
#         GiftDate  GiftAmount  GiftCode ZipCode5 State Gender MaritalStatus  \
# 26660  7/13/2018         0.0        24      NaN   NaN    NaN           NaN
# 26659  7/13/2018         0.0        21      NaN   NaN    NaN           NaN
# 26661  7/13/2018         0.0        12      NaN   NaN    NaN           NaN
# 26656  7/13/2018         0.0         5      NaN   NaN    NaN           NaN
# 26655  7/13/2018         0.0        11      NaN   NaN    NaN           NaN
#
#        BirthYear  AgeAtGift  Age  Deceased
# 26660        NaN        NaN  NaN         0
# 26659        NaN        NaN  NaN         0
# 26661        NaN        NaN  NaN         0
# 26656        NaN        NaN  NaN         0
# 26655        NaN        NaN  NaN         0

# %%
'''try a few more independent variables, see results'''
#look at state
import operator

def analyzeIndependentVariable(independentVar):
    varDict = {}
    for index, row in df.iterrows():
        variable = row[independentVar]
        if variable != "nan":
            if variable in varDict:
                varDict[variable] = [varDict[variable][0], varDict[variable][1] + row["GiftAmount"], varDict[variable][2] + 1]
            else:
                varDict[variable] = [index, row["GiftAmount"], 1]

    for key, value in varDict.items():
        varDict[key] = [varDict[key][1]/varDict[key][2], varDict[key][2]]

    sortedDictHighAvg = dict(sorted(varDict.items(), key=operator.itemgetter(1), reverse=True)[:5])
    sortedDictLowAvg = dict(sorted(varDict.items(), key=operator.itemgetter(1), reverse=False)[:5])
    sortedDictHighCount = dict(sorted(varDict.items(), key=lambda x: x[1][1], reverse=True)[:5])
    sortedDictLowCount = dict(sorted(varDict.items(), key=lambda x: x[1][1], reverse=False)[:5])

    return varDict, sortedDictHighAvg, sortedDictLowAvg, sortedDictHighCount, sortedDictLowCount

stateDict, sortedDictHighAvg, sortedDictLowAvg, sortedDictHighCount, sortedDictLowCount = analyzeIndependentVariable("State")
print(sortedDictHighAvg)
print(sortedDictLowAvg)
print(sortedDictHighCount)
print(sortedDictLowCount)
# Out:
# {'me': [136544.676, 5], 'hi': [105834.03111111112, 9], 'nh': [91720.41666666667, 27], 'ga': [83669.50353846155, 65], 'ae': [83180.0, 5]}
# {'ap': [1000.0, 1], 'dc': [1000.0, 3], 'as': [2500.0, 1], 'nj': [2959.7411626506, 1660], 'sc': [4891.42074074074, 81]}
# {'mn': [26493.670730268517, 2458], 'wi': [25110.013050064183, 2337], 'mo': [35909.4481853095, 2294], 'il': [31686.553878461542, 1950], 'mi': [22540.276409560018, 1841]}
# {'ap': [1000.0, 1], 'as': [2500.0, 1], 'dc': [1000.0, 3], 'ae': [83180.0, 5], 'me': [136544.676, 5]}

# %%
def prettyPrintDict(dictionary):
    for key, value in dictionary.items():
        print(str(key) + " | " + str(value[0]) + " | " + str(value[1]))
        
prettyPrintDict(sortedDictLowCount)
# Out:
# ap | 1000.0 | 1
# as | 2500.0 | 1
# dc | 1000.0 | 3
# ae | 83180.0 | 5
# me | 136544.676 | 5

# %% [markdown]
# State | Average Donation ($) | Number of Donations
# --|--|--
# ap | 1000.0 | 1
# as | 2500.0 | 1
# dc | 1000.0 | 3
# ae | 83180.0 | 5
# me | 136544.676 | 5

# %%
'''try zip code'''

zipDict, sortedDictHighAvg, sortedDictLowAvg, sortedDictHighCount, sortedDictLowCount = analyzeIndependentVariable("ZipCode5")
    
print(sortedDictHighAvg)
print(sortedDictLowAvg)
print(sortedDictHighCount)
print(sortedDictLowCount)
# Out:
# {'65049': [5402615.0, 1], '33067': [2480000.0, 1], '98407': [2100000.0, 1], '67402': [1647279.6666666667, 3], '60143': [1290166.6666666667, 3]}
# {'58801': [1.0, 1], '75701': [1.0, 1], '68343': [1.0, 2], '48030': [1.0, 3], '22152': [1.0, 5]}
# {nan: [96984.5844559586, 386], '32765': [21659.160483870968, 217], '46514': [2462.8750632911324, 158], '56031': [26657.207337662316, 154], '68434': [35225.86749999999, 152]}
# {'68862': [600.0, 1], '32505': [1000.0, 1], '7042': [10000.0, 1], '22407': [1000.0, 1], '53525': [2000.0, 1]}

# %%
prettyPrintDict(sortedDictLowCount)
# Out:
# 68862 | 600.0 | 1
# 32505 | 1000.0 | 1
# 7042 | 10000.0 | 1
# 22407 | 1000.0 | 1
# 53525 | 2000.0 | 1

# %% [markdown]
# Zip Code | Average Donation ($) | Number of Donations
# --|--|--
# 68862 | 600.0 | 1
# 32505 | 1000.0 | 1
# 7042 | 10000.0 | 1
# 22407 | 1000.0 | 1
# 53525 | 2000.0 | 1

# %%
'''try marital status'''

maritalStatusDict = {}
for index, row in df.iterrows():
    married = row["MaritalStatus"]
    if str(married) != "nan":
        if married in maritalStatusDict:
            maritalStatusDict[married] = [maritalStatusDict[married][0], maritalStatusDict[married][1] + row["GiftAmount"], maritalStatusDict[married][2] + 1]
        else:
            maritalStatusDict[married] = [index, row["GiftAmount"], 1]

for key, value in maritalStatusDict.items():
    maritalStatusDict[key] = [maritalStatusDict[key][1]/maritalStatusDict[key][2], maritalStatusDict[key][2]]
    
print(maritalStatusDict)

prettyPrintDict(maritalStatusDict)
# Out:
# {'married': [30173.151209176733, 13589], 'widow': [75090.942839779, 905], 'widowed': [33602.34934706545, 1772], 'single': [26462.13000781305, 2803], 'divorced': [43440.126081081085, 74], 'separated': [290104.9442307692, 26], 'u': [5000.0, 1]}
# married | 30173.151209176733 | 13589
# widow | 75090.942839779 | 905
# widowed | 33602.34934706545 | 1772
# single | 26462.13000781305 | 2803
# divorced | 43440.126081081085 | 74
# separated | 290104.9442307692 | 26
# u | 5000.0 | 1

# %% [markdown]
# Marital Status | Average Donation ($) | Number of Donations
# --|--|--
# married | 30173.151209176733 | 13589
# widow | 75090.942839779 | 905
# widowed | 33602.34934706545 | 1772
# single | 26462.13000781305 | 2803
# divorced | 43440.126081081085 | 74
# separated | 290104.9442307692 | 26

# %%
'''try age at gift'''

ageDonationArray = []
for index, row in df.iterrows():
    age = row["AgeAtGift"]
    donation = row["GiftAmount"]
    if str(age) != "nan":
        ageDonationArray.append((age, donation))
        
ageDict = {}
rangeCounter = 0
amountRanges = np.linspace(0, 150, 50)
for age, amount in sorted(ageDonationArray, key = lambda x: x[0], reverse = False):
    while age > amountRanges[rangeCounter] and rangeCounter < len(amountRanges) - 1:
        rangeCounter += 1
    if amountRanges[rangeCounter] in ageDict:
        ageDict[amountRanges[rangeCounter]][0] += amount
        ageDict[amountRanges[rangeCounter]][1] += 1
    else:
        ageDict[amountRanges[rangeCounter]] = [amount, 1]

x = []
y = []
yAvg = []

for key, value in ageDict.items():
    averageValue = value[0]/value[1]
    x.append(key)
    y.append(averageValue)
    

plt.scatter(x, y)
plt.plot(x, y)
plt.title("Age vs Average Amount Donated")
plt.xlabel("Amount Donated")
plt.ylabel("Age")
# Out:
# Text(0,0.5,'Age')

# %%
'''total donations per year'''
import re

yearDonationArray = []
for index, row in df.iterrows():
    date = row["GiftDate"]
    match = re.search(r'(\d+)\/(\d+)\/(\d+)', date)
    year = match.group(3)
    donation = row["GiftAmount"]
    if str(year) != "nan":
        yearDonationArray.append((year, donation))
        
yearDict = {}
for year, amount in sorted(yearDonationArray, key = lambda x: x[0], reverse = False):
    if year in yearDict:
        yearDict[year][0] += amount
        yearDict[year][1] += 1
    else:
        yearDict[year] = [amount, 1]

x = []
yAmount = []
yCount = []

for key, value in yearDict.items():
#    averageValue = value[0]/value[1]
    averageValue = value[0]
    x.append(int(key))
    yAmount.append(float(averageValue))
    yCount.append(int(value[1]))
    
plt.figure(1)
plt.rcParams['figure.figsize'] = [10, 10]

plt.subplot(221)
plt.scatter(x, yAmount)
z = np.polyfit(x, yAmount, 1)
p = np.poly1d(z)
plt.plot(x, p(x), 'r--')
plt.plot(x, yAmount)
plt.xlim(xmin=1965)
plt.title("Total Donation Amount")
plt.xlabel("Year")
plt.ylabel("Amount")

plt.subplot(222)
plt.scatter(x, yCount)
z = np.polyfit(x, yCount, 1)
p = np.poly1d(z)
plt.plot(x, p(x), 'r--')
plt.plot(x, yCount)
plt.xlim(xmin=1965)
plt.title("Total Number of Donations")
plt.xlabel("Year")
plt.ylabel("Amount")

plt.show()

# %%
'''regresion with number of people who donates as well as year of donations'''
from sklearn.linear_model import LinearRegression as linReg
from sklearn.model_selection import train_test_split as crossval

features = []
labels = []

for key, value in yearDict.items():
    features.append([int(key), value[1]])
    labels.append(value[0])

scores = []
for x in range(100):
    XTrain, XTest, yTrain, yTest = crossval(features, labels, test_size = 0.2)
    model = linReg().fit(XTrain, yTrain)
    scores.append(model.score(XTest, yTest))
    
scores = np.array(scores)
print(f"Mean score in 100 trials is: {np.average(scores)} with SD {np.std(scores)}")
# Out:
# Mean score in 100 trials is: 0.6563365068201508 with SD 0.2109761077790646

# %%
'''linear combination of different regressions'''

yearAgeArray = []
yearArray = []
ageArray = []
for index, row in df.iterrows():
    age = row["AgeAtGift"]
    year = re.search(r'(\d+)\/(\d+)\/(\d+)', row["GiftDate"]).group(3)
    yearArray.append(year)
    if str(age) != "nan":
        yearAgeArray.append((year, age))

yearArray = sorted(set(yearArray))


ageYearDict = {}
rangeCounter = 0
amountRanges = np.linspace(0, 150, 50)
for year, age in sorted(yearAgeArray, key = lambda x: x[1], reverse = False):
    while age > amountRanges[rangeCounter] and rangeCounter < len(amountRanges) - 1:
        rangeCounter += 1
    roundedAge = round(amountRanges[rangeCounter])
    if year in ageYearDict:
        if roundedAge in ageYearDict[year]:
            ageYearDict[year][roundedAge] += 1
        else:
            ageYearDict[year][roundedAge] = 1
    else:
        ageYearDict[year] = {roundedAge : 1}

# for year, ageDict in sorted(ageYearDict.items(), reverse = False):
#     for x in amountRanges:
#         x = round(x)
#         ageDict

ageYearTimeDict = {}

for age in amountRanges:
    ageYearCount = []
    age = round(age)
    for year in yearArray:
        if age in ageYearDict[year]:
            ageYearCount.append(ageYearDict[year][age])
        else:
            ageYearCount.append(0)
    ageYearTimeDict[age] = ageYearCount
    
yearArray = np.array([int(year) for year in yearArray]).reshape(-1, 1)
ageModelDict = {}

for age, counts in ageYearTimeDict.items():
    model = linReg().fit(yearArray, counts)
    ageModelDict[age] = model
    
roundedAgeDict = {}
for age, amount in ageDict.items():
    roundedAgeDict[round(age)] = amount
    
predictedSums = {}
for year in yearArray:
    for age, model in ageModelDict.items():
        print(f"In year {year}, predict {model.predict(2012)} number of {age} year olds will donate.")
# Out:
# In year [1970], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1970], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1970], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1970], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1970], predict [0.] number of 12.0 year olds will donate.
# In year [1970], predict [0.] number of 15.0 year olds will donate.
# In year [1970], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1970], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1970], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1970], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1970], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1970], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1970], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1970], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1970], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1970], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1970], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1970], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1970], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1970], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1970], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1970], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1970], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1970], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1970], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1970], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1970], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1970], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1970], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1970], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1970], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1970], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1970], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1970], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1970], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1970], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1970], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1970], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1970], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1970], predict [0.] number of 119.0 year olds will donate.
# In year [1970], predict [0.] number of 122.0 year olds will donate.
# In year [1970], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1970], predict [0.] number of 129.0 year olds will donate.
# In year [1970], predict [0.] number of 132.0 year olds will donate.
# In year [1970], predict [0.] number of 135.0 year olds will donate.
# In year [1970], predict [0.] number of 138.0 year olds will donate.
# In year [1970], predict [0.] number of 141.0 year olds will donate.
# In year [1970], predict [0.] number of 144.0 year olds will donate.
# In year [1970], predict [0.] number of 147.0 year olds will donate.
# In year [1970], predict [0.] number of 150.0 year olds will donate.
# In year [1971], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1971], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1971], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1971], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1971], predict [0.] number of 12.0 year olds will donate.
# In year [1971], predict [0.] number of 15.0 year olds will donate.
# In year [1971], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1971], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1971], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1971], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1971], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1971], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1971], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1971], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1971], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1971], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1971], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1971], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1971], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1971], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1971], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1971], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1971], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1971], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1971], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1971], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1971], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1971], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1971], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1971], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1971], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1971], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1971], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1971], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1971], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1971], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1971], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1971], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1971], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1971], predict [0.] number of 119.0 year olds will donate.
# In year [1971], predict [0.] number of 122.0 year olds will donate.
# In year [1971], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1971], predict [0.] number of 129.0 year olds will donate.
# In year [1971], predict [0.] number of 132.0 year olds will donate.
# In year [1971], predict [0.] number of 135.0 year olds will donate.
# In year [1971], predict [0.] number of 138.0 year olds will donate.
# In year [1971], predict [0.] number of 141.0 year olds will donate.
# In year [1971], predict [0.] number of 144.0 year olds will donate.
# In year [1971], predict [0.] number of 147.0 year olds will donate.
# In year [1971], predict [0.] number of 150.0 year olds will donate.
# In year [1972], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1972], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1972], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1972], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1972], predict [0.] number of 12.0 year olds will donate.
# In year [1972], predict [0.] number of 15.0 year olds will donate.
# In year [1972], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1972], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1972], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1972], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1972], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1972], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1972], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1972], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1972], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1972], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1972], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1972], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1972], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1972], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1972], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1972], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1972], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1972], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1972], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1972], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1972], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1972], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1972], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1972], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1972], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1972], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1972], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1972], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1972], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1972], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1972], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1972], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1972], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1972], predict [0.] number of 119.0 year olds will donate.
# In year [1972], predict [0.] number of 122.0 year olds will donate.
# In year [1972], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1972], predict [0.] number of 129.0 year olds will donate.
# In year [1972], predict [0.] number of 132.0 year olds will donate.
# In year [1972], predict [0.] number of 135.0 year olds will donate.
# In year [1972], predict [0.] number of 138.0 year olds will donate.
# In year [1972], predict [0.] number of 141.0 year olds will donate.
# In year [1972], predict [0.] number of 144.0 year olds will donate.
# In year [1972], predict [0.] number of 147.0 year olds will donate.
# In year [1972], predict [0.] number of 150.0 year olds will donate.
# In year [1973], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1973], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1973], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1973], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1973], predict [0.] number of 12.0 year olds will donate.
# In year [1973], predict [0.] number of 15.0 year olds will donate.
# In year [1973], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1973], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1973], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1973], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1973], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1973], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1973], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1973], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1973], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1973], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1973], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1973], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1973], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1973], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1973], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1973], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1973], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1973], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1973], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1973], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1973], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1973], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1973], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1973], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1973], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1973], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1973], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1973], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1973], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1973], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1973], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1973], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1973], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1973], predict [0.] number of 119.0 year olds will donate.
# In year [1973], predict [0.] number of 122.0 year olds will donate.
# In year [1973], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1973], predict [0.] number of 129.0 year olds will donate.
# In year [1973], predict [0.] number of 132.0 year olds will donate.
# In year [1973], predict [0.] number of 135.0 year olds will donate.
# In year [1973], predict [0.] number of 138.0 year olds will donate.
# In year [1973], predict [0.] number of 141.0 year olds will donate.
# In year [1973], predict [0.] number of 144.0 year olds will donate.
# In year [1973], predict [0.] number of 147.0 year olds will donate.
# In year [1973], predict [0.] number of 150.0 year olds will donate.
# In year [1974], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1974], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1974], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1974], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1974], predict [0.] number of 12.0 year olds will donate.
# In year [1974], predict [0.] number of 15.0 year olds will donate.
# In year [1974], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1974], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1974], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1974], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1974], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1974], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1974], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1974], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1974], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1974], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1974], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1974], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1974], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1974], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1974], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1974], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1974], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1974], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1974], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1974], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1974], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1974], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1974], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1974], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1974], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1974], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1974], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1974], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1974], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1974], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1974], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1974], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1974], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1974], predict [0.] number of 119.0 year olds will donate.
# In year [1974], predict [0.] number of 122.0 year olds will donate.
# In year [1974], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1974], predict [0.] number of 129.0 year olds will donate.
# In year [1974], predict [0.] number of 132.0 year olds will donate.
# In year [1974], predict [0.] number of 135.0 year olds will donate.
# In year [1974], predict [0.] number of 138.0 year olds will donate.
# In year [1974], predict [0.] number of 141.0 year olds will donate.
# In year [1974], predict [0.] number of 144.0 year olds will donate.
# In year [1974], predict [0.] number of 147.0 year olds will donate.
# In year [1974], predict [0.] number of 150.0 year olds will donate.
# In year [1975], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1975], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1975], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1975], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1975], predict [0.] number of 12.0 year olds will donate.
# In year [1975], predict [0.] number of 15.0 year olds will donate.
# In year [1975], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1975], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1975], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1975], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1975], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1975], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1975], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1975], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1975], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1975], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1975], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1975], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1975], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1975], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1975], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1975], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1975], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1975], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1975], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1975], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1975], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1975], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1975], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1975], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1975], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1975], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1975], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1975], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1975], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1975], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1975], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1975], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1975], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1975], predict [0.] number of 119.0 year olds will donate.
# In year [1975], predict [0.] number of 122.0 year olds will donate.
# In year [1975], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1975], predict [0.] number of 129.0 year olds will donate.
# In year [1975], predict [0.] number of 132.0 year olds will donate.
# In year [1975], predict [0.] number of 135.0 year olds will donate.
# In year [1975], predict [0.] number of 138.0 year olds will donate.
# In year [1975], predict [0.] number of 141.0 year olds will donate.
# In year [1975], predict [0.] number of 144.0 year olds will donate.
# In year [1975], predict [0.] number of 147.0 year olds will donate.
# In year [1975], predict [0.] number of 150.0 year olds will donate.
# In year [1976], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1976], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1976], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1976], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1976], predict [0.] number of 12.0 year olds will donate.
# In year [1976], predict [0.] number of 15.0 year olds will donate.
# In year [1976], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1976], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1976], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1976], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1976], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1976], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1976], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1976], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1976], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1976], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1976], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1976], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1976], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1976], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1976], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1976], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1976], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1976], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1976], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1976], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1976], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1976], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1976], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1976], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1976], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1976], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1976], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1976], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1976], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1976], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1976], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1976], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1976], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1976], predict [0.] number of 119.0 year olds will donate.
# In year [1976], predict [0.] number of 122.0 year olds will donate.
# In year [1976], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1976], predict [0.] number of 129.0 year olds will donate.
# In year [1976], predict [0.] number of 132.0 year olds will donate.
# In year [1976], predict [0.] number of 135.0 year olds will donate.
# In year [1976], predict [0.] number of 138.0 year olds will donate.
# In year [1976], predict [0.] number of 141.0 year olds will donate.
# In year [1976], predict [0.] number of 144.0 year olds will donate.
# In year [1976], predict [0.] number of 147.0 year olds will donate.
# In year [1976], predict [0.] number of 150.0 year olds will donate.
# In year [1977], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1977], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1977], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1977], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1977], predict [0.] number of 12.0 year olds will donate.
# In year [1977], predict [0.] number of 15.0 year olds will donate.
# In year [1977], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1977], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1977], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1977], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1977], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1977], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1977], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1977], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1977], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1977], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1977], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1977], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1977], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1977], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1977], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1977], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1977], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1977], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1977], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1977], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1977], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1977], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1977], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1977], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1977], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1977], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1977], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1977], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1977], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1977], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1977], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1977], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1977], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1977], predict [0.] number of 119.0 year olds will donate.
# In year [1977], predict [0.] number of 122.0 year olds will donate.
# In year [1977], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1977], predict [0.] number of 129.0 year olds will donate.
# In year [1977], predict [0.] number of 132.0 year olds will donate.
# In year [1977], predict [0.] number of 135.0 year olds will donate.
# In year [1977], predict [0.] number of 138.0 year olds will donate.
# In year [1977], predict [0.] number of 141.0 year olds will donate.
# In year [1977], predict [0.] number of 144.0 year olds will donate.
# In year [1977], predict [0.] number of 147.0 year olds will donate.
# In year [1977], predict [0.] number of 150.0 year olds will donate.
# In year [1978], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1978], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1978], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1978], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1978], predict [0.] number of 12.0 year olds will donate.
# In year [1978], predict [0.] number of 15.0 year olds will donate.
# In year [1978], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1978], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1978], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1978], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1978], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1978], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1978], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1978], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1978], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1978], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1978], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1978], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1978], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1978], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1978], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1978], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1978], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1978], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1978], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1978], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1978], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1978], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1978], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1978], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1978], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1978], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1978], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1978], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1978], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1978], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1978], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1978], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1978], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1978], predict [0.] number of 119.0 year olds will donate.
# In year [1978], predict [0.] number of 122.0 year olds will donate.
# In year [1978], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1978], predict [0.] number of 129.0 year olds will donate.
# In year [1978], predict [0.] number of 132.0 year olds will donate.
# In year [1978], predict [0.] number of 135.0 year olds will donate.
# In year [1978], predict [0.] number of 138.0 year olds will donate.
# In year [1978], predict [0.] number of 141.0 year olds will donate.
# In year [1978], predict [0.] number of 144.0 year olds will donate.
# In year [1978], predict [0.] number of 147.0 year olds will donate.
# In year [1978], predict [0.] number of 150.0 year olds will donate.
# In year [1979], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1979], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1979], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1979], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1979], predict [0.] number of 12.0 year olds will donate.
# In year [1979], predict [0.] number of 15.0 year olds will donate.
# In year [1979], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1979], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1979], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1979], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1979], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1979], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1979], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1979], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1979], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1979], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1979], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1979], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1979], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1979], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1979], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1979], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1979], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1979], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1979], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1979], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1979], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1979], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1979], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1979], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1979], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1979], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1979], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1979], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1979], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1979], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1979], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1979], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1979], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1979], predict [0.] number of 119.0 year olds will donate.
# In year [1979], predict [0.] number of 122.0 year olds will donate.
# In year [1979], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1979], predict [0.] number of 129.0 year olds will donate.
# In year [1979], predict [0.] number of 132.0 year olds will donate.
# In year [1979], predict [0.] number of 135.0 year olds will donate.
# In year [1979], predict [0.] number of 138.0 year olds will donate.
# In year [1979], predict [0.] number of 141.0 year olds will donate.
# In year [1979], predict [0.] number of 144.0 year olds will donate.
# In year [1979], predict [0.] number of 147.0 year olds will donate.
# In year [1979], predict [0.] number of 150.0 year olds will donate.
# In year [1980], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1980], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1980], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1980], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1980], predict [0.] number of 12.0 year olds will donate.
# In year [1980], predict [0.] number of 15.0 year olds will donate.
# In year [1980], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1980], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1980], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1980], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1980], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1980], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1980], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1980], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1980], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1980], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1980], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1980], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1980], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1980], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1980], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1980], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1980], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1980], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1980], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1980], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1980], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1980], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1980], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1980], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1980], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1980], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1980], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1980], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1980], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1980], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1980], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1980], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1980], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1980], predict [0.] number of 119.0 year olds will donate.
# In year [1980], predict [0.] number of 122.0 year olds will donate.
# In year [1980], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1980], predict [0.] number of 129.0 year olds will donate.
# In year [1980], predict [0.] number of 132.0 year olds will donate.
# In year [1980], predict [0.] number of 135.0 year olds will donate.
# In year [1980], predict [0.] number of 138.0 year olds will donate.
# In year [1980], predict [0.] number of 141.0 year olds will donate.
# In year [1980], predict [0.] number of 144.0 year olds will donate.
# In year [1980], predict [0.] number of 147.0 year olds will donate.
# In year [1980], predict [0.] number of 150.0 year olds will donate.
# In year [1981], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1981], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1981], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1981], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1981], predict [0.] number of 12.0 year olds will donate.
# In year [1981], predict [0.] number of 15.0 year olds will donate.
# In year [1981], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1981], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1981], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1981], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1981], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1981], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1981], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1981], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1981], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1981], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1981], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1981], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1981], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1981], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1981], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1981], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1981], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1981], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1981], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1981], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1981], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1981], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1981], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1981], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1981], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1981], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1981], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1981], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1981], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1981], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1981], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1981], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1981], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1981], predict [0.] number of 119.0 year olds will donate.
# In year [1981], predict [0.] number of 122.0 year olds will donate.
# In year [1981], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1981], predict [0.] number of 129.0 year olds will donate.
# In year [1981], predict [0.] number of 132.0 year olds will donate.
# In year [1981], predict [0.] number of 135.0 year olds will donate.
# In year [1981], predict [0.] number of 138.0 year olds will donate.
# In year [1981], predict [0.] number of 141.0 year olds will donate.
# In year [1981], predict [0.] number of 144.0 year olds will donate.
# In year [1981], predict [0.] number of 147.0 year olds will donate.
# In year [1981], predict [0.] number of 150.0 year olds will donate.
# In year [1982], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1982], predict [0.04244898] number of 3.0 year olds will donate.
# In year [1982], predict [0.01489796] number of 6.0 year olds will donate.
# In year [1982], predict [0.1055102] number of 9.0 year olds will donate.
# In year [1982], predict [0.] number of 12.0 year olds will donate.
# In year [1982], predict [0.] number of 15.0 year olds will donate.
# In year [1982], predict [0.01857143] number of 18.0 year olds will donate.
# In year [1982], predict [0.33081633] number of 21.0 year olds will donate.
# In year [1982], predict [0.25510204] number of 24.0 year olds will donate.
# In year [1982], predict [0.09081633] number of 28.0 year olds will donate.
# In year [1982], predict [0.21510204] number of 31.0 year olds will donate.
# In year [1982], predict [0.39897959] number of 34.0 year olds will donate.
# In year [1982], predict [0.78959184] number of 37.0 year olds will donate.
# In year [1982], predict [1.77530612] number of 40.0 year olds will donate.
# In year [1982], predict [1.83755102] number of 43.0 year olds will donate.
# In year [1982], predict [3.8855102] number of 46.0 year olds will donate.
# In year [1982], predict [6.03122449] number of 49.0 year olds will donate.
# In year [1982], predict [8.53285714] number of 52.0 year olds will donate.
# In year [1982], predict [11.27387755] number of 55.0 year olds will donate.
# In year [1982], predict [16.73693878] number of 58.0 year olds will donate.
# In year [1982], predict [18.98469388] number of 61.0 year olds will donate.
# In year [1982], predict [26.80877551] number of 64.0 year olds will donate.
# In year [1982], predict [29.44836735] number of 67.0 year olds will donate.
# In year [1982], predict [40.43469388] number of 70.0 year olds will donate.
# In year [1982], predict [50.29755102] number of 73.0 year olds will donate.
# In year [1982], predict [64.05081633] number of 77.0 year olds will donate.
# In year [1982], predict [67.05306122] number of 80.0 year olds will donate.
# In year [1982], predict [75.17428571] number of 83.0 year olds will donate.
# In year [1982], predict [71.58081633] number of 86.0 year olds will donate.
# In year [1982], predict [62.55897959] number of 89.0 year olds will donate.
# In year [1982], predict [45.96938776] number of 92.0 year olds will donate.
# In year [1982], predict [28.62571429] number of 95.0 year olds will donate.
# In year [1982], predict [14.04877551] number of 98.0 year olds will donate.
# In year [1982], predict [8.33469388] number of 101.0 year olds will donate.
# In year [1982], predict [1.17285714] number of 104.0 year olds will donate.
# In year [1982], predict [0.77632653] number of 107.0 year olds will donate.
# In year [1982], predict [0.09591837] number of 110.0 year olds will donate.
# In year [1982], predict [0.16040816] number of 113.0 year olds will donate.
# In year [1982], predict [0.04979592] number of 116.0 year olds will donate.
# In year [1982], predict [0.] number of 119.0 year olds will donate.
# In year [1982], predict [0.] number of 122.0 year olds will donate.
# In year [1982], predict [0.05897959] number of 126.0 year olds will donate.
# In year [1982], predict [0.] number of 129.0 year olds will donate.
# In year [1982], predict [0.] number of 132.0 year olds will donate.
# In year [1982], predict [0.] number of 135.0 year olds will donate.
# In year [1982], predict [0.] number of 138.0 year olds will donate.
# In year [1982], predict [0.] number of 141.0 year olds will donate.
# In year [1982], predict [0.] number of 144.0 year olds will donate.
# In year [1982], predict [0.] number of 147.0 year olds will donate.
# In year [1982], predict [0.] number of 150.0 year olds will donate.
# In year [1983], predict [0.2955102] number of 0.0 year olds will donate.
# In year [1983], predict [0.04244898] number of 3.0 year olds will donate.
# ...
# In year [2014], predict [8.33469388] number of 101.0 year olds will donate.
# In year [2014], predict [1.17285714] number of 104.0 year olds will donate.
# In year [2014], predict [0.77632653] number of 107.0 year olds will donate.
# In year [2014], predict [0.09591837] number of 110.0 year olds will donate.
# In year [2014], predict [0.16040816] number of 113.0 year olds will donate.
# In year [2014], predict [0.04979592] number of 116.0 year olds will donate.
# In year [2014], predict [0.] number of 119.0 year olds will donate.
# In year [2014], predict [0.] number of 122.0 year olds will donate.
# In year [2014], predict [0.05897959] number of 126.0 year olds will donate.
# In year [2014], predict [0.] number of 129.0 year olds will donate.
# In year [2014], predict [0.] number of 132.0 year olds will donate.
# In year [2014], predict [0.] number of 135.0 year olds will donate.
# In year [2014], predict [0.] number of 138.0 year olds will donate.
# In year [2014], predict [0.] number of 141.0 year olds will donate.
# In year [2014], predict [0.] number of 144.0 year olds will donate.
# In year [2014], predict [0.] number of 147.0 year olds will donate.
# In year [2014], predict [0.] number of 150.0 year olds will donate.
# In year [2015], predict [0.2955102] number of 0.0 year olds will donate.
# In year [2015], predict [0.04244898] number of 3.0 year olds will donate.
# In year [2015], predict [0.01489796] number of 6.0 year olds will donate.
# In year [2015], predict [0.1055102] number of 9.0 year olds will donate.
# In year [2015], predict [0.] number of 12.0 year olds will donate.
# In year [2015], predict [0.] number of 15.0 year olds will donate.
# In year [2015], predict [0.01857143] number of 18.0 year olds will donate.
# In year [2015], predict [0.33081633] number of 21.0 year olds will donate.
# In year [2015], predict [0.25510204] number of 24.0 year olds will donate.
# In year [2015], predict [0.09081633] number of 28.0 year olds will donate.
# In year [2015], predict [0.21510204] number of 31.0 year olds will donate.
# In year [2015], predict [0.39897959] number of 34.0 year olds will donate.
# In year [2015], predict [0.78959184] number of 37.0 year olds will donate.
# In year [2015], predict [1.77530612] number of 40.0 year olds will donate.
# In year [2015], predict [1.83755102] number of 43.0 year olds will donate.
# In year [2015], predict [3.8855102] number of 46.0 year olds will donate.
# In year [2015], predict [6.03122449] number of 49.0 year olds will donate.
# In year [2015], predict [8.53285714] number of 52.0 year olds will donate.
# In year [2015], predict [11.27387755] number of 55.0 year olds will donate.
# In year [2015], predict [16.73693878] number of 58.0 year olds will donate.
# In year [2015], predict [18.98469388] number of 61.0 year olds will donate.
# In year [2015], predict [26.80877551] number of 64.0 year olds will donate.
# In year [2015], predict [29.44836735] number of 67.0 year olds will donate.
# In year [2015], predict [40.43469388] number of 70.0 year olds will donate.
# In year [2015], predict [50.29755102] number of 73.0 year olds will donate.
# In year [2015], predict [64.05081633] number of 77.0 year olds will donate.
# In year [2015], predict [67.05306122] number of 80.0 year olds will donate.
# In year [2015], predict [75.17428571] number of 83.0 year olds will donate.
# In year [2015], predict [71.58081633] number of 86.0 year olds will donate.
# In year [2015], predict [62.55897959] number of 89.0 year olds will donate.
# In year [2015], predict [45.96938776] number of 92.0 year olds will donate.
# In year [2015], predict [28.62571429] number of 95.0 year olds will donate.
# In year [2015], predict [14.04877551] number of 98.0 year olds will donate.
# In year [2015], predict [8.33469388] number of 101.0 year olds will donate.
# In year [2015], predict [1.17285714] number of 104.0 year olds will donate.
# In year [2015], predict [0.77632653] number of 107.0 year olds will donate.
# In year [2015], predict [0.09591837] number of 110.0 year olds will donate.
# In year [2015], predict [0.16040816] number of 113.0 year olds will donate.
# In year [2015], predict [0.04979592] number of 116.0 year olds will donate.
# In year [2015], predict [0.] number of 119.0 year olds will donate.
# In year [2015], predict [0.] number of 122.0 year olds will donate.
# In year [2015], predict [0.05897959] number of 126.0 year olds will donate.
# In year [2015], predict [0.] number of 129.0 year olds will donate.
# In year [2015], predict [0.] number of 132.0 year olds will donate.
# In year [2015], predict [0.] number of 135.0 year olds will donate.
# In year [2015], predict [0.] number of 138.0 year olds will donate.
# In year [2015], predict [0.] number of 141.0 year olds will donate.
# In year [2015], predict [0.] number of 144.0 year olds will donate.
# In year [2015], predict [0.] number of 147.0 year olds will donate.
# In year [2015], predict [0.] number of 150.0 year olds will donate.
# In year [2016], predict [0.2955102] number of 0.0 year olds will donate.
# In year [2016], predict [0.04244898] number of 3.0 year olds will donate.
# In year [2016], predict [0.01489796] number of 6.0 year olds will donate.
# In year [2016], predict [0.1055102] number of 9.0 year olds will donate.
# In year [2016], predict [0.] number of 12.0 year olds will donate.
# In year [2016], predict [0.] number of 15.0 year olds will donate.
# In year [2016], predict [0.01857143] number of 18.0 year olds will donate.
# In year [2016], predict [0.33081633] number of 21.0 year olds will donate.
# In year [2016], predict [0.25510204] number of 24.0 year olds will donate.
# In year [2016], predict [0.09081633] number of 28.0 year olds will donate.
# In year [2016], predict [0.21510204] number of 31.0 year olds will donate.
# In year [2016], predict [0.39897959] number of 34.0 year olds will donate.
# In year [2016], predict [0.78959184] number of 37.0 year olds will donate.
# In year [2016], predict [1.77530612] number of 40.0 year olds will donate.
# In year [2016], predict [1.83755102] number of 43.0 year olds will donate.
# In year [2016], predict [3.8855102] number of 46.0 year olds will donate.
# In year [2016], predict [6.03122449] number of 49.0 year olds will donate.
# In year [2016], predict [8.53285714] number of 52.0 year olds will donate.
# In year [2016], predict [11.27387755] number of 55.0 year olds will donate.
# In year [2016], predict [16.73693878] number of 58.0 year olds will donate.
# In year [2016], predict [18.98469388] number of 61.0 year olds will donate.
# In year [2016], predict [26.80877551] number of 64.0 year olds will donate.
# In year [2016], predict [29.44836735] number of 67.0 year olds will donate.
# In year [2016], predict [40.43469388] number of 70.0 year olds will donate.
# In year [2016], predict [50.29755102] number of 73.0 year olds will donate.
# In year [2016], predict [64.05081633] number of 77.0 year olds will donate.
# In year [2016], predict [67.05306122] number of 80.0 year olds will donate.
# In year [2016], predict [75.17428571] number of 83.0 year olds will donate.
# In year [2016], predict [71.58081633] number of 86.0 year olds will donate.
# In year [2016], predict [62.55897959] number of 89.0 year olds will donate.
# In year [2016], predict [45.96938776] number of 92.0 year olds will donate.
# In year [2016], predict [28.62571429] number of 95.0 year olds will donate.
# In year [2016], predict [14.04877551] number of 98.0 year olds will donate.
# In year [2016], predict [8.33469388] number of 101.0 year olds will donate.
# In year [2016], predict [1.17285714] number of 104.0 year olds will donate.
# In year [2016], predict [0.77632653] number of 107.0 year olds will donate.
# In year [2016], predict [0.09591837] number of 110.0 year olds will donate.
# In year [2016], predict [0.16040816] number of 113.0 year olds will donate.
# In year [2016], predict [0.04979592] number of 116.0 year olds will donate.
# In year [2016], predict [0.] number of 119.0 year olds will donate.
# In year [2016], predict [0.] number of 122.0 year olds will donate.
# In year [2016], predict [0.05897959] number of 126.0 year olds will donate.
# In year [2016], predict [0.] number of 129.0 year olds will donate.
# In year [2016], predict [0.] number of 132.0 year olds will donate.
# In year [2016], predict [0.] number of 135.0 year olds will donate.
# In year [2016], predict [0.] number of 138.0 year olds will donate.
# In year [2016], predict [0.] number of 141.0 year olds will donate.
# In year [2016], predict [0.] number of 144.0 year olds will donate.
# In year [2016], predict [0.] number of 147.0 year olds will donate.
# In year [2016], predict [0.] number of 150.0 year olds will donate.
# In year [2017], predict [0.2955102] number of 0.0 year olds will donate.
# In year [2017], predict [0.04244898] number of 3.0 year olds will donate.
# In year [2017], predict [0.01489796] number of 6.0 year olds will donate.
# In year [2017], predict [0.1055102] number of 9.0 year olds will donate.
# In year [2017], predict [0.] number of 12.0 year olds will donate.
# In year [2017], predict [0.] number of 15.0 year olds will donate.
# In year [2017], predict [0.01857143] number of 18.0 year olds will donate.
# In year [2017], predict [0.33081633] number of 21.0 year olds will donate.
# In year [2017], predict [0.25510204] number of 24.0 year olds will donate.
# In year [2017], predict [0.09081633] number of 28.0 year olds will donate.
# In year [2017], predict [0.21510204] number of 31.0 year olds will donate.
# In year [2017], predict [0.39897959] number of 34.0 year olds will donate.
# In year [2017], predict [0.78959184] number of 37.0 year olds will donate.
# In year [2017], predict [1.77530612] number of 40.0 year olds will donate.
# In year [2017], predict [1.83755102] number of 43.0 year olds will donate.
# In year [2017], predict [3.8855102] number of 46.0 year olds will donate.
# In year [2017], predict [6.03122449] number of 49.0 year olds will donate.
# In year [2017], predict [8.53285714] number of 52.0 year olds will donate.
# In year [2017], predict [11.27387755] number of 55.0 year olds will donate.
# In year [2017], predict [16.73693878] number of 58.0 year olds will donate.
# In year [2017], predict [18.98469388] number of 61.0 year olds will donate.
# In year [2017], predict [26.80877551] number of 64.0 year olds will donate.
# In year [2017], predict [29.44836735] number of 67.0 year olds will donate.
# In year [2017], predict [40.43469388] number of 70.0 year olds will donate.
# In year [2017], predict [50.29755102] number of 73.0 year olds will donate.
# In year [2017], predict [64.05081633] number of 77.0 year olds will donate.
# In year [2017], predict [67.05306122] number of 80.0 year olds will donate.
# In year [2017], predict [75.17428571] number of 83.0 year olds will donate.
# In year [2017], predict [71.58081633] number of 86.0 year olds will donate.
# In year [2017], predict [62.55897959] number of 89.0 year olds will donate.
# In year [2017], predict [45.96938776] number of 92.0 year olds will donate.
# In year [2017], predict [28.62571429] number of 95.0 year olds will donate.
# In year [2017], predict [14.04877551] number of 98.0 year olds will donate.
# In year [2017], predict [8.33469388] number of 101.0 year olds will donate.
# In year [2017], predict [1.17285714] number of 104.0 year olds will donate.
# In year [2017], predict [0.77632653] number of 107.0 year olds will donate.
# In year [2017], predict [0.09591837] number of 110.0 year olds will donate.
# In year [2017], predict [0.16040816] number of 113.0 year olds will donate.
# In year [2017], predict [0.04979592] number of 116.0 year olds will donate.
# In year [2017], predict [0.] number of 119.0 year olds will donate.
# In year [2017], predict [0.] number of 122.0 year olds will donate.
# In year [2017], predict [0.05897959] number of 126.0 year olds will donate.
# In year [2017], predict [0.] number of 129.0 year olds will donate.
# In year [2017], predict [0.] number of 132.0 year olds will donate.
# In year [2017], predict [0.] number of 135.0 year olds will donate.
# In year [2017], predict [0.] number of 138.0 year olds will donate.
# In year [2017], predict [0.] number of 141.0 year olds will donate.
# In year [2017], predict [0.] number of 144.0 year olds will donate.
# In year [2017], predict [0.] number of 147.0 year olds will donate.
# In year [2017], predict [0.] number of 150.0 year olds will donate.
# In year [2018], predict [0.2955102] number of 0.0 year olds will donate.
# In year [2018], predict [0.04244898] number of 3.0 year olds will donate.
# In year [2018], predict [0.01489796] number of 6.0 year olds will donate.
# In year [2018], predict [0.1055102] number of 9.0 year olds will donate.
# In year [2018], predict [0.] number of 12.0 year olds will donate.
# In year [2018], predict [0.] number of 15.0 year olds will donate.
# In year [2018], predict [0.01857143] number of 18.0 year olds will donate.
# In year [2018], predict [0.33081633] number of 21.0 year olds will donate.
# In year [2018], predict [0.25510204] number of 24.0 year olds will donate.
# In year [2018], predict [0.09081633] number of 28.0 year olds will donate.
# In year [2018], predict [0.21510204] number of 31.0 year olds will donate.
# In year [2018], predict [0.39897959] number of 34.0 year olds will donate.
# In year [2018], predict [0.78959184] number of 37.0 year olds will donate.
# In year [2018], predict [1.77530612] number of 40.0 year olds will donate.
# In year [2018], predict [1.83755102] number of 43.0 year olds will donate.
# In year [2018], predict [3.8855102] number of 46.0 year olds will donate.
# In year [2018], predict [6.03122449] number of 49.0 year olds will donate.
# In year [2018], predict [8.53285714] number of 52.0 year olds will donate.
# In year [2018], predict [11.27387755] number of 55.0 year olds will donate.
# In year [2018], predict [16.73693878] number of 58.0 year olds will donate.
# In year [2018], predict [18.98469388] number of 61.0 year olds will donate.
# In year [2018], predict [26.80877551] number of 64.0 year olds will donate.
# In year [2018], predict [29.44836735] number of 67.0 year olds will donate.
# In year [2018], predict [40.43469388] number of 70.0 year olds will donate.
# In year [2018], predict [50.29755102] number of 73.0 year olds will donate.
# In year [2018], predict [64.05081633] number of 77.0 year olds will donate.
# In year [2018], predict [67.05306122] number of 80.0 year olds will donate.
# In year [2018], predict [75.17428571] number of 83.0 year olds will donate.
# In year [2018], predict [71.58081633] number of 86.0 year olds will donate.
# In year [2018], predict [62.55897959] number of 89.0 year olds will donate.
# In year [2018], predict [45.96938776] number of 92.0 year olds will donate.
# In year [2018], predict [28.62571429] number of 95.0 year olds will donate.
# In year [2018], predict [14.04877551] number of 98.0 year olds will donate.
# In year [2018], predict [8.33469388] number of 101.0 year olds will donate.
# In year [2018], predict [1.17285714] number of 104.0 year olds will donate.
# In year [2018], predict [0.77632653] number of 107.0 year olds will donate.
# In year [2018], predict [0.09591837] number of 110.0 year olds will donate.
# In year [2018], predict [0.16040816] number of 113.0 year olds will donate.
# In year [2018], predict [0.04979592] number of 116.0 year olds will donate.
# In year [2018], predict [0.] number of 119.0 year olds will donate.
# In year [2018], predict [0.] number of 122.0 year olds will donate.
# In year [2018], predict [0.05897959] number of 126.0 year olds will donate.
# In year [2018], predict [0.] number of 129.0 year olds will donate.
# In year [2018], predict [0.] number of 132.0 year olds will donate.
# In year [2018], predict [0.] number of 135.0 year olds will donate.
# In year [2018], predict [0.] number of 138.0 year olds will donate.
# In year [2018], predict [0.] number of 141.0 year olds will donate.
# In year [2018], predict [0.] number of 144.0 year olds will donate.
# In year [2018], predict [0.] number of 147.0 year olds will donate.
# In year [2018], predict [0.] number of 150.0 year olds will donate.

# %%
'''knn with several different variables'''
# Out:
# 'knn with several different variables'
